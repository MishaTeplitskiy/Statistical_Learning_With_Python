# %% [markdown]
# #Statistical Learning with Python
#
# Agenda:
#
# **Intro and Plugs**
# - Sociology / computational social science
# - <a href=http://www.knowledgelab.org>www.knowledgelab.org</a>
# - <a href=http://www.dssg.io>www.dssg.io</a>
#
# **IPython Notebook** as your IDE
#     - Advantages/disadvantages
#         - notebook: markdown, code, inline images
#         - server
#         - "--script"
#     - Sharing is caring: http://nbviewer.ipython.org/
#     - Keyboard shortcuts

# %% [markdown]
# <img src=http://i.minus.com/iEdBFdHPKBG8Q.gif>

# %% [markdown]
# **Pandas**

# %% [markdown]
#     - Creating Series and DataFrames
#         - Setting column names, index, datatypes
#     - Indexing
#         - By index, by label
#     - Subsetting
#     - Missing values

# %% [markdown]
# <img src=http://img3.wikia.nocookie.net/__cb20131231081108/degrassi/images/9/93/Panda-gif.gif>

# %% [markdown]
# **Matplotlib**
#     - scatter, plot, hist
#     - useful plot customazation
#     - plots inside of pandas
#
# **Regression Example**
#
# **Classification Example**

# %% [markdown]
# <img src=http://www.totalprosports.com/wp-content/uploads/2012/11/14-nolan-ryan-high-fives-george-w-bush-gif.gif>

# %%
# %matplotlib inline

# %% [markdown]
# #Pandas

# %%
import pandas as pd

# %% [markdown]
# Provides a crucial 2-d data structure: the ``pandas.DataFrame``
#     - pandas.Series is 1-d analogue
#     - Like the ``R`` data frames
#
# ``numpy`` does too, BUT ``pandas``
#
#   1. can hold *heterogenous data*; each column can have its own data type,
#   2. the axes of a DataFrame are *labeled* with column names and row indices,
#
# Perfect for data-wrangling: can take subsets, apply functions, join with other DataFrames, etc.

# %%
# Load car dataset
df = pd.read_csv('http://www-bcf.usc.edu/~gareth/ISL/Auto.csv')
df.head()  # print the first lines
# Out:
#    mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0   18          8           307        130    3504          12.0    70
# 1   15          8           350        165    3693          11.5    70
# 2   18          8           318        150    3436          11.0    70
# 3   16          8           304        150    3433          12.0    70
# 4   17          8           302        140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
print 'Shape of DataFrame:', df.shape
print '\nColumns:', df.columns
print '\nIndex:', df.index[:10]
# Out:
# Shape of DataFrame: (397, 9)
#
# Columns: Index([u'mpg', u'cylinders', u'displacement', u'horsepower', u'weight', u'acceleration', u'year', u'origin', u'name'], dtype='object')
#
# Index: Index([u'chevrolet chevelle malibu', u'buick skylark 320', u'plymouth satellite', u'amc rebel sst', u'ford torino', u'ford galaxie 500', u'chevrolet impala', u'plymouth fury iii', u'pontiac catalina', u'amc ambassador dpl'], dtype='object')

# %% [markdown]
# ###Get the ``df`` nice and cozy

# %%
df.index = df.name
del df['name']
df.head()
# Out:
#                            mpg  cylinders  displacement horsepower  weight  \
# name
# chevrolet chevelle malibu   18          8           307        130    3504
# buick skylark 320           15          8           350        165    3693
# plymouth satellite          18          8           318        150    3436
# amc rebel sst               16          8           304        150    3433
# ford torino                 17          8           302        140    3449
#
#                            acceleration  year  origin
# name
# chevrolet chevelle malibu          12.0    70       1
# buick skylark 320                  11.5    70       1
# plymouth satellite                 11.0    70       1
# amc rebel sst                      12.0    70       1
# ford torino                        10.5    70       1

# %% [markdown]
# ###Accessing, adding data
# You can use the dot ``.`` or bracket ``[]`` notation to access columns of the dataset. To add new columns you have to use the bracket ``[]`` notation

# %%
mpg = df.mpg  # get mpg column using '.'
weight = df['weight']  # get weight column using brackets
df['mpg_per_weight'] = mpg / weight # note the element-wise division

print df[['mpg', 'weight', 'mpg_per_weight']].head()  # get a bunch of columns at the same time
# Out:
#    mpg  weight  mpg_per_weight
# 0   18    3504        0.005137
# 1   15    3693        0.004062
# 2   18    3436        0.005239
# 3   16    3433        0.004661
# 4   17    3449        0.004929

# %% [markdown]
# ##Looking at data

# %% [markdown]
# ###Pandas indexing is really smart!

# %%
# To look at all the Fords, create array of length = #rows of True and False, where True if 'ford' in string
arr_for_indexing = ['ford' in name for name in df.index]
df[arr_for_indexing].head()
# Out:
#                   mpg  cylinders  displacement horsepower  weight  \
# name
# ford torino        17          8           302        140    3449
# ford galaxie 500   15          8           429        198    4341
# ford maverick      21          6           200         85    2587
# ford f250          10          8           360        215    4615
# ford pinto         25          4            98          ?    2046
#
#                   acceleration  year  origin
# name
# ford torino               10.5    70       1
# ford galaxie 500          10.0    70       1
# ford maverick             16.0    70       1
# ford f250                 14.0    70       1
# ford pinto                19.0    71       1

# %% [markdown]
# ###But it can get confused: Indexing by "label" and by "location", ``.loc`` vs ``.iloc`` vs ``.ix``

# %% [markdown]
# ``.loc`` -- by label
#
# ``.iloc`` -- by location
#
# ``.ix`` -- by a mix

# %%
df.ix[0:5, ['weight', 'mpg']]  # select the first 5 rows and two columns weight and mpg
# Out:
#                                    weight  mpg
# name
# chevrolet chevelle malibu            3504   18
# buick skylark 320                    3693   15
# plymouth satellite                   3436   18
# amc rebel sst                        3433   16
# ford torino                          3449   17
# ford galaxie 500                     4341   15
# chevrolet impala                     4354   14
# plymouth fury iii                    4312   14
# pontiac catalina                     4425   14
# amc ambassador dpl                   3850   15
# dodge challenger se                  3563   15
# plymouth 'cuda 340                   3609   14
# chevrolet monte carlo                3761   15
# buick estate wagon (sw)              3086   14
# toyota corona mark ii                2372   24
# plymouth duster                      2833   22
# amc hornet                           2774   18
# ford maverick                        2587   21
# datsun pl510                         2130   27
# volkswagen 1131 deluxe sedan         1835   26
# peugeot 504                          2672   25
# audi 100 ls                          2430   24
# saab 99e                             2375   25
# bmw 2002                             2234   26
# amc gremlin                          2648   21
# ford f250                            4615   10
# chevy c20                            4376   10
# dodge d200                           4382   11
# hi 1200d                             4732    9
# datsun pl510                         2130   27
# ...                                   ...  ...
# chevrolet cavalier                   2605   28
# chevrolet cavalier wagon             2640   27
# chevrolet cavalier 2-door            2395   34
# pontiac j2000 se hatchback           2575   31
# dodge aries se                       2525   29
# pontiac phoenix                      2735   27
# ford fairmont futura                 2865   24
# volkswagen rabbit l                  1980   36
# mazda glc custom l                   2025   37
# mazda glc custom                     1970   31
# plymouth horizon miser               2125   38
# mercury lynx l                       2125   36
# nissan stanza xe                     2160   36
# honda accord                         2205   36
# toyota corolla                       2245   34
# honda civic                          1965   38
# honda civic (auto)                   1965   32
# datsun 310 gx                        1995   38
# buick century limited                2945   25
# oldsmobile cutlass ciera (diesel)    3015   38
# chrysler lebaron medallion           2585   26
# ford granada l                       2835   22
# toyota celica gt                     2665   32
# dodge charger 2.2                    2370   36
# chevrolet camaro                     2950   27
# ford mustang gl                      2790   27
# vw pickup                            2130   44
# dodge rampage                        2295   32
# ford ranger                          2625   28
# chevy s-10                           2720   31
#
# [397 rows x 2 columns]

# %%
# useful function!: value_counts()
df.year.value_counts()
# Out:
# 1973    40
# 1978    36
# 1976    34
# 1975    30
# 1982    30
# 1980    29
# 1970    29
# 1979    29
# 1981    29
# 1971    28
# 1972    28
# 1977    28
# 1974    27
# dtype: int64

# %% [markdown]
# ###Let's change year from "70" to "1970"

# %%
df.year.apply(lambda x: '19' + str(x)) # this spits out the Series we like
# df.year = df.year.apply(lambda x: '19' + str(x))
# Out:
# name
# chevrolet chevelle malibu    191970
# buick skylark 320            191970
# plymouth satellite           191970
# amc rebel sst                191970
# ford torino                  191970
# ford galaxie 500             191970
# chevrolet impala             191970
# plymouth fury iii            191970
# pontiac catalina             191970
# amc ambassador dpl           191970
# dodge challenger se          191970
# plymouth 'cuda 340           191970
# chevrolet monte carlo        191970
# buick estate wagon (sw)      191970
# toyota corona mark ii        191970
# ...
# honda civic                          191982
# honda civic (auto)                   191982
# datsun 310 gx                        191982
# buick century limited                191982
# oldsmobile cutlass ciera (diesel)    191982
# chrysler lebaron medallion           191982
# ford granada l                       191982
# toyota celica gt                     191982
# dodge charger 2.2                    191982
# chevrolet camaro                     191982
# ford mustang gl                      191982
# vw pickup                            191982
# dodge rampage                        191982
# ford ranger                          191982
# chevy s-10                           191982
# Name: year, Length: 397, dtype: object

# %%
#Uh oh, let's change it back!
df.year = df.year.str[-2:]
# Out:
# name
# chevrolet chevelle malibu    70
# buick skylark 320            70
# plymouth satellite           70
# amc rebel sst                70
# ford torino                  70
# ford galaxie 500             70
# chevrolet impala             70
# plymouth fury iii            70
# pontiac catalina             70
# amc ambassador dpl           70
# dodge challenger se          70
# plymouth 'cuda 340           70
# chevrolet monte carlo        70
# buick estate wagon (sw)      70
# toyota corona mark ii        70
# ...
# honda civic                          82
# honda civic (auto)                   82
# datsun 310 gx                        82
# buick century limited                82
# oldsmobile cutlass ciera (diesel)    82
# chrysler lebaron medallion           82
# ford granada l                       82
# toyota celica gt                     82
# dodge charger 2.2                    82
# chevrolet camaro                     82
# ford mustang gl                      82
# vw pickup                            82
# dodge rampage                        82
# ford ranger                          82
# chevy s-10                           82
# Name: year, Length: 397, dtype: object

# %% [markdown]
# #Visualizing data

# %% [markdown]
# Most popular library: ``matplotlib``
#
# Others:
# - ``seaborn``
# - ``ggplot``
# - ``prettyplotlib``
# - ``bokeh``

# %% [markdown]
# ### common matplotlib plots
# - plt.hist <-- histograms
# - plt.scatter <-- scatter plot
# - plt.plot <-- most others

# %%
import matplotlib.pyplot as plt
plt.hist(df.weight)
# Out:
# (array([ 31.,  90.,  59.,  54.,  36.,  40.,  29.,  34.,  18.,   6.]),
#  array([ 1613. ,  1965.7,  2318.4,  2671.1,  3023.8,  3376.5,  3729.2,
#          4081.9,  4434.6,  4787.3,  5140. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ### common plot features to tweak
# - plt.title('Sk00l Rox', fontsize=20)
# - plt.xlabel('')
# - plt.ylabel('')
# - plt.xlim(min, max)
# - plt.legend()

# %% [markdown]
# ###We can also used pandas' ``plot`` and other plotting function!!!

# %%
df.weight.hist()
plt.title('OMG THERES A TITLE!!!11', fontsize=20)

# let's add decoration
plt.xlabel('weight')
plt.ylabel('frequency')
plt.xlim(0, df.weight.max())
plt.legend()

# %%
plt.scatter(df.year, df.weight)

# %%
df.boxplot('weight')
# df.boxplot('weight', 'year')
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7a02950>],
#  'caps': [<matplotlib.lines.Line2D at 0x7a02190>,
#   <matplotlib.lines.Line2D at 0x7a02570>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7a09130>,
#   <matplotlib.lines.Line2D at 0x7a096f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7a02d30>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x79f9c10>,
#   <matplotlib.lines.Line2D at 0x79f9df0>]}

# %%
from pandas.tools.plotting import scatter_matrix
_ = scatter_matrix(df[['mpg', 'cylinders', 'displacement']], figsize=(14, 10))

# %% [markdown]
# #Regression next. But first...

# %% [markdown]
# <img src=http://replygif.net/i/209.gif>

# %%
plt.xkcd()

# %%
df.weight.hist()
plt.title('WOT, THERES AN XKCD STYLE???', fontsize=18)
plt.xlabel('weight')
plt.ylabel('freq.')
